# %% [markdown]
# # INTEGRANTES
#
#
# *   Luis Ernesto Rodriguez Felacio
# *   Andrés David Ariza Granados

# %%
# IMPORT librerias

import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
#Obtener Datos

df = pd.read_csv("./Recuperaci_n_Veh_culos_Polic_a_Nacional.csv")

# %%
# Previsualizar datos
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Dimensiones del dataframe

df.shape
# Out:
# (1000, 8)

# %%
# Columnas del dataframe

df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# Tipos de datos de las columnas del dataframe

df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
# Cantidad de registros del dataset

print("Dataset length", len(df))
# Out:
# Dataset length 1000

# %%
#renombrar columnas del dataset

name = ['Genero','Etnia', 'Educacion Padres', 'Almuerzo','Preparacion Examenes','Calif. Matematicas','Calif. Lectura','Calif. Escritura']
df.columns = name
df.columns
# Out:
# Index(['Genero', 'Etnia', 'Educacion Padres', 'Almuerzo',
#        'Preparacion Examenes', 'Calif. Matematicas', 'Calif. Lectura',
#        'Calif. Escritura'],
#       dtype='object')

# %%
# Mostrar los valores únicos en cada columna
for columna in df.columns:
    valores_unicos = df[columna].value_counts()
    print(f"Valores en la columna {columna}:\n{valores_unicos}\n")
# Out:
# Valores en la columna Genero:
# Genero
# female    518
# male      482
# Name: count, dtype: int64
#
# Valores en la columna Etnia:
# Etnia
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
#
# Valores en la columna Educacion Padres:
# Educacion Padres
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
#
# Valores en la columna Almuerzo:
# Almuerzo
# standard        645
# free/reduced    355
# Name: count, dtype: int64
#
# Valores en la columna Preparacion Examenes:
# Preparacion Examenes
# none         642
# completed    358
# Name: count, dtype: int64
#
# Valores en la columna Calif. Matematicas:
# Calif. Matematicas
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: count, Length: 81, dtype: int64
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Genero                1000 non-null   object
#  1   Etnia                 1000 non-null   object
#  2   Educacion Padres      1000 non-null   object
#  3   Almuerzo              1000 non-null   object
#  4   Preparacion Examenes  1000 non-null   object
#  5   Calif. Matematicas    1000 non-null   int64
#  6   Calif. Lectura        1000 non-null   int64
#  7   Calif. Escritura      1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#Codificar las columnas con valores String

# Crear un diccionario de mapeo
map_genero = {'female': 1, 'male': 2}
mapeo_etnia = {'group A': 1, 'group B': 2, 'group C': 3, 'group D': 4, 'group E': 5}
mapeo_educacion_padres = {'some college': 1, "associate's degree": 2, 'high school': 3, 'some high school': 4, "bachelor's degree": 5, "master's degree": 6}
mapeo_almuerzo = {'standard': 1, 'free/reduced': 2}
mapeo_curso = {'none': 0, 'completed': 1}

# Aplicar los mapeos a la columnas indicadas
df['Cod_Genero'] = df['Genero'].map(map_genero)
df['Cod_Etnia'] = df['Etnia'].map(mapeo_etnia)
df['Cod_Educacion_Padres'] = df['Educacion Padres'].map(mapeo_educacion_padres)
df['Cod_Almuerzo'] = df['Almuerzo'].map(mapeo_almuerzo)
df['Cod_Preparacion_Examenes'] = df['Preparacion Examenes'].map(mapeo_curso)

# %%
# Organizar el DataFrame después de la codificación

columnas_ordenadas = ['Genero','Cod_Genero','Etnia','Cod_Etnia','Educacion Padres','Cod_Educacion_Padres','Almuerzo','Cod_Almuerzo',
                      'Preparacion Examenes','Cod_Preparacion_Examenes','Calif. Matematicas','Calif. Lectura','Calif. Escritura']
df = df[columnas_ordenadas]

df.sample(10)
# Out:
#      Genero  Cod_Genero    Etnia  Cod_Etnia    Educacion Padres  \
# 171    male           2  group E          5    some high school
# 14   female           1  group A          1     master's degree
# 454  female           1  group C          3  associate's degree
# 459    male           2  group B          2         high school
# 807  female           1  group E          5         high school
# 913  female           1  group C          3   bachelor's degree
# 281    male           2  group D          4         high school
# 826  female           1  group C          3  associate's degree
# 429    male           2  group C          3    some high school
# 125  female           1  group B          2         high school
#
#      Cod_Educacion_Padres      Almuerzo  Cod_Almuerzo Preparacion Examenes  \
# 171                     4      standard             1                 none
# 14                      6      standard             1                 none
# ...
